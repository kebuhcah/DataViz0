# %%
from bs4 import BeautifulSoup
from pandas import DataFrame
import pandas as pd
import string

# %%
bs=BeautifulSoup(open("data.html"))

# %%
t=bs.div.find_all("div")

# %%
for d in t:
    try:
        print d["class"]
    except KeyError:
        print
# Out:
# ['gridStyle', 'ng-scope', 'ngGrid', 'ng1488593293588']
# ['ngTopPanel', 'ng-scope']
# ['ngGroupPanel', 'ng-hide']
# ['ngGroupPanelDescription', 'ng-binding']
# ['ngHeaderContainer']
# ['ngHeaderScroller']
# ['ngHeaderCell', 'ng-scope', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt0']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt1']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt2']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt3']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt4']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt5']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt6']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt7']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt8']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt9']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt10']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt11']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt12']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
# ['ngHeaderCell', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ngVerticalBar']
#
# ['ngHeaderSortColumn', 'ngSorted']
# ['ngHeaderText', 'ng-binding', 'colt13']
# ['ngSortButtonDown', 'ng-hide']
# ['ngSortButtonUp', 'ng-hide']
# ['ngSortPriority', 'ng-binding']
# ['ng-hide', 'ngUnPinnedIcon']
# ['ngHeaderGrip', 'ng-scope']
#
# ['ngHeaderButton', 'ng-scope', 'ng-hide']
# ['ngHeaderButtonArrow']
# ['ngColMenu', 'ng-scope', 'ng-hide']
# ['ng-hide']
# ['ng-hide']
# ['ngViewport', 'ng-scope']
# ['ngCanvas']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'even']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope', 'ngRow', 'odd']
# ['ngCell', 'col0', 'colt0']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col0', 'colt0']
# ['ngCell', 'col1', 'colt1']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col1', 'colt1']
# ['ngCell', 'col2', 'colt2']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col2', 'colt2']
# ['ngCell', 'col3', 'colt3']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col3', 'colt3']
# ['ngCell', 'grid-align-right', 'col4', 'colt4']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col4', 'colt4', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col5', 'colt5']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col5', 'colt5', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col6', 'colt6']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col6', 'colt6', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col7', 'colt7']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col7', 'colt7', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col8', 'colt8']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col8', 'colt8', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col9', 'colt9']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col9', 'colt9', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col10', 'colt10']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col10', 'colt10', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col11', 'colt11']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col11', 'colt11', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col12', 'colt12']
# ['ngVerticalBar', 'ngVerticalBarVisible']
#
# ['ngCellText', 'ng-scope', 'col12', 'colt12', 'grid-align-right']
# ['ngCell', 'grid-align-right', 'col13', 'colt13']
# ['ngVerticalBar']
#
# ['ngCellText', 'ng-scope', 'col13', 'colt13', 'grid-align-right']
# ['ng-scope']
# ['ngFooterPanel', 'ng-scope', 'ng-hide']
# ['ngTotalSelectContainer']
# ['ngFooterTotalItems', 'ngNoMultiSelect']
# ['ngFooterSelectedItems', 'ng-hide']
# ['ngPagerContainer', 'ngNoMultiSelect', 'ng-hide']
# ['ngRowCountPicker']
# ['ngPagerControl']
# ['ngPagerFirstTriangle']
# ['ngPagerFirstBar']
# ['ngPagerFirstTriangle', 'ngPagerPrevTriangle']
# ['ngPagerLastTriangle', 'ngPagerNextTriangle']
# ['ngPagerLastTriangle']
# ['ngPagerLastBar']

# %%
colnamemap={header["class"][-1]:string.strip(header.getText()) for header in bs.find_all("div",class_="ngHeaderText")}
colnamemap
# Out:
# {'colt0': u'Year',
#  'colt1': u'Country / territory of asylum/residence',
#  'colt10': u'Otherwise closed',
#  'colt11': u'Total decisions',
#  'colt12': u'Total persons pending end-year',
#  'colt13': u'of which UNHCR-assisted',
#  'colt2': u'Origin',
#  'colt3': u'RSD procedure type / level',
#  'colt4': u'Total persons pending start-year',
#  'colt5': u'of which UNHCR-assisted',
#  'colt6': u'Applied during year',
#  'colt7': u'Recognized',
#  'colt8': u'Other',
#  'colt9': u'Rejected'}

# %%
rowcontents=[{cell["class"][3]:string.strip(cell.getText()) 
              for cell in row.find_all("div", class_="ngCellText")} 
              for row in bs.find_all("div",class_="ngRow")]

t=DataFrame(rowcontents)[['colt'+str(i) for i in range(14)]].rename(columns=colnamemap)
t.columns=['year','destination','origin','typeLevel','totalYearStart','totalYearStartUnhcr',
          'appliedDuringYear','recognized','other','rejected','otherClosed','totalDecisions','totalYearEnd','totalYearEndUnhcr']
t[t.typeLevel=='U / FI']
# Out:
#     year destination       origin typeLevel totalYearStart  \
# 1   2015   Indonesia  Afghanistan    U / FI          4,052
# 2   2014   Indonesia  Afghanistan    U / FI          2,760
# 5   2013   Indonesia  Afghanistan    U / FI          2,951
# 9   2009   Indonesia  Afghanistan    U / FI            136
# 11  2008   Indonesia  Afghanistan    U / FI             12
# 16  2003   Indonesia  Afghanistan    U / FI             47
# 17  2002   Indonesia  Afghanistan    U / FI            447
# 18  2001   Indonesia  Afghanistan    U / FI            110
# 19  2000   Indonesia  Afghanistan    U / FI              4
#
#    totalYearStartUnhcr appliedDuringYear recognized other rejected  \
# 1                4,052             1,315      1,462             59
# 2                2,760             3,627      1,023     0      174
# 5                2,951             3,392        960     0       81
# 9                  136             2,304        256     0       34
# 11                  12               149          6     0       10
# 16                  47                 9         14     0       30
# 17                 447               281        133     8      139
# 18                 110               687         12     0       14
# 19                   4               196         29     0       12
#
#    otherClosed totalDecisions totalYearEnd totalYearEndUnhcr
# 1          171          1,692        3,675             3,675
# 2        1,138          2,335        4,052             4,052
# 5        2,542          3,583        2,760             2,760
# 9          753          1,043        1,397             1,397
# 11           9             25          136               136
# 16           9             53            3                 3
# 17         401            681           47                47
# 18         324            350          447               447
# 19          49             90          110               110
